# %%
import pandas as pd

# %%
disease = pd.read_csv('..//data/cholera-dataset.csv')

# %%
disease
# Out:
#      Unnamed: 0  age     sex  dh  rbp      c  seizures  vc   ga  bt0  fc  \
# 0             0   63    Male   3  145  233.0         1   0  150    0   0
# 1             1   37    Male   2  130  250.0         0   1  187    0   0
# 2             2   41  Female   1  130  204.0         0   0  172    0   2
# 3             3   56    Male   1  120  236.0         0   1  178    0   2
# 4             4   57  Female   0  120  354.0         0   1  163    1   2
# 5             5   57    Male   0  140  192.0         0   1  148    0   1
# 6             6   56  Female   1  140  294.0         0   0  153    0   1
# 7             7   44    Male   1  120  263.0         0   1  173    0   2
# 8             8   52    Male   2  172  199.0         1   1  162    0   2
# 9             9   57    Male   2  150  168.0         0   1  174    0   2
# 10           10   54    Male   0  140  239.0         0   1  160    0   2
# 11           11   48  Female   2  130  275.0         0   1  139    0   2
# ...
