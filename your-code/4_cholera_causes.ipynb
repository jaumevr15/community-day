# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
disease = pd.read_csv('..//data/clean_df.csv',index_col=0)

# %%
disease.head()
# Out:
#    age     sex  dh  rbp      c  seizures  vc   ga  bt0  fc  exposed_to  fever  \
# 0   63    Male   3  145  233.0         1   0  150    0   0         0.0      0
# 1   37    Male   2  130  250.0         0   1  187    0   0         0.0      0
# 2   41  Female   1  130  204.0         0   0  172    0   2         0.0      0
# 3   56    Male   1  120  236.0         0   1  178    0   2         0.0      0
# 4   57  Female   0  120  354.0         0   1  163    1   2         0.0      0
#
#    cholera
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
import statsmodels.api as sm
Z = sm.add_constant(disease[['age','dh','rbp','ga','fc']])
model = sm.OLS(disease.cholera,Z)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                cholera   R-squared:                       0.338
# Model:                            OLS   Adj. R-squared:                  0.327
# Method:                 Least Squares   F-statistic:                     30.38
# Date:                Fri, 22 Nov 2019   Prob (F-statistic):           6.34e-25
# Time:                        16:25:35   Log-Likelihood:                -156.13
# No. Observations:                 303   AIC:                             324.3
# Df Residuals:                     297   BIC:                             346.5
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0130      0.285     -0.046      0.964      -0.574       0.548
# ...
